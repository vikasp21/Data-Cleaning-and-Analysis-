# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=pd.read_csv('Netflixdata.csv')
data
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
data.shape
# Out:
# (2500, 10)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2500, step=1)

# %%
data.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %%
data.dtypes
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %%
data.describe().sum()
# Out:
# User ID            10724.832160
# Monthly Revenue     2576.195251
# Age                 2738.967378
# dtype: float64

# %%
data.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
data.describe(include='object')
# Out:
#        Subscription Type Join Date Last Payment Date        Country  Gender  \
# count               2500      2500              2500           2500    2500
# unique                 3       300                26             10       2
# top                Basic  05-11-22          28-06-23  United States  Female
# freq                 999        33               164            451    1257
#
#         Device Plan Duration
# count     2500          2500
# unique       4             1
# top     Laptop       1 Month
# freq       636          2500

# %%
data.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# User ID              2500
# Subscription Type       3
# Monthly Revenue         6
# Join Date             300
# Last Payment Date      26
# Country                10
# Age                    26
# Gender                  2
# Device                  4
# Plan Duration           1
# dtype: int64

# %%
data.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
data['Country'].value_counts()
# Out:
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: Country, dtype: int64

# %%
data['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Australia',
#        'Germany', 'France', 'Brazil', 'Mexico', 'Spain', 'Italy'],
#       dtype=object)

# %%
 data.groupby('Country').get_group('Canada')
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 1           2           Premium               15  05-09-21          22-06-23
# 11         12           Premium               15  23-03-23          28-06-23
# 21         22             Basic               10  22-07-22          28-06-23
# 31         32             Basic               10  07-07-22          28-06-23
# 41         42             Basic               10  15-06-22          28-06-23
# ...       ...               ...              ...       ...               ...
# 2468     2469           Premium               12  24-10-22          11-07-23
# 2471     2472             Basic               14  29-09-22          14-07-23
# 2483     2484          Standard               11  29-07-22          13-07-23
# 2486     2487           Premium               11  25-07-22          12-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
#
# ...

# %%
data.groupby('Country').get_group('Italy')
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 9          10           Premium               15  07-01-23          22-06-23
# 19         20             Basic               10  27-05-23          22-06-23
# 29         30             Basic               10  17-05-23          22-06-23
# 39         40             Basic               10  07-03-23          22-06-23
# 49         50             Basic               10  02-06-23          22-06-23
# ...       ...               ...              ...       ...               ...
# 2434     2435             Basic               14  06-09-22          13-07-23
# 2449     2450             Basic               13  29-10-22          13-07-23
# 2464     2465             Basic               15  03-11-22          11-07-23
# 2479     2480             Basic               13  07-08-22          14-07-23
# 2494     2495             Basic               15  23-07-22          12-07-23
#
# ...

# %%
data.groupby('Country').get_group('Germany')
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 4           5             Basic               10  01-05-23          28-06-23
# 14         15          Standard               12  09-05-23          28-06-23
# 24         25             Basic               10  14-03-23          28-06-23
# 34         35             Basic               10  11-04-23          28-06-23
# 44         45             Basic               10  28-01-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2429     2430             Basic               10  13-08-22          11-07-23
# 2444     2445             Basic               14  16-10-22          10-07-23
# 2459     2460             Basic               15  12-11-22          13-07-23
# 2474     2475             Basic               12  05-09-22          11-07-23
# 2489     2490          Standard               10  17-07-22          15-07-23
#
# ...

# %%
data.groupby('Age').get_group(35)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 1           2           Premium               15  05-09-21          22-06-23
# 35         36           Premium               15  01-03-22          27-06-23
# 81         82          Standard               12  07-12-22          28-06-23
# 92         93          Standard               12  05-02-22          26-06-23
# 99        100             Basic               12  22-01-23          25-06-23
# ...       ...               ...              ...       ...               ...
# 2405     2406           Premium               13  30-08-22          15-07-23
# 2459     2460             Basic               15  12-11-22          13-07-23
# 2486     2487           Premium               11  25-07-22          12-07-23
# 2489     2490          Standard               10  17-07-22          15-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
data.groupby('Gender').get_group('Male')
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# 6           7          Standard               12  09-12-21          25-06-23
# 8           9          Standard               12  20-10-22          23-06-23
# ...       ...               ...              ...       ...               ...
# 2486     2487           Premium               11  25-07-22          12-07-23
# 2489     2490          Standard               10  17-07-22          15-07-23
# 2492     2493          Standard               11  20-07-22          11-07-23
# 2493     2494           Premium               12  21-07-22          15-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
#
# ...

# %%
plt.figure(figsize=(15,13))
plt.bar(x=data["Country"],
       height=data["Monthly Revenue"],
       color="midnightblue")
plt.xticks(rotation=45,fontsize=14)
plt.yticks(fontsize=13)
plt.title("Netflix Visualization",fontsize=15,weight="bold")
plt.ylabel("dataset on monthly revenue",fontsize=15,weight="bold")
plt.show()

# %%
plt.figure(figsize=(15,13))
plt.bar(x=data["Country"],
       height=data["Subscription Type"],
       color="midnightblue")
plt.title("Netflix Visualization",fontsize=15,weight="bold")
plt.ylabel("dataset on monthly revenue",fontsize=15,weight="bold")
sns.despine()
plt.show()
